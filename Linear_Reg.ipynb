# %% [markdown]
# <a href="https://colab.research.google.com/github/Zartern/Zartern/blob/main/Linear_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import pandas as pd

# %%
rng = np.random
# x = rng.rand(100)*100
# print(x)


x=np.linspace(-5,5,100)
y=2*x+rng.rand(100)*10
plt.scatter(x,y)

model = LinearRegression()

x_new = x.reshape(-1,1)
model.fit(x_new,y)
print(model.coef_)
print(model.intercept_)
y_pred = model.predict(x_new)
plt.plot(x_new,y_pred,'-r')
# Out:
# [1.99932316]
# 5.299978240938378

# %%
data = pd.read_csv('housing.csv', header=None, delimiter=r"\s+", names=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'])

print(data.head(5))
print(np.shape(data))
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# (506, 14)

# %%
data = data[~(data['MEDV'] >= 50.0)]
print(np.shape(data))
# Out:
# (490, 14)

# %%
y = data['MEDV']
x = data['LSTAT']
x = x.values.reshape(-1,1)
model.fit(x,y)
print(model.coef_)
print(model.intercept_)
y_pred = model.predict(x)
plt.scatter(x,y)
plt.plot(x,y_pred,'-r')
plt.show()
# Out:
# [-0.84373838]
# 32.5404103783323

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print(metrics.mean_squared_error(y_test,y_pred))
print(metrics.mean_absolute_error(y_test,y_pred))
print(metrics.r2_score(y_test,y_pred))
# Out:
# 23.011569663593217
# 3.914836409675047
# 0.6375213352194817
